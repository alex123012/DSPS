# %% [markdown]
# ## Запускаем базу

# %%
# !{ podman stop postgres && podman rm postgres; } || true
# !podman run --rm --name postgres -e POSTGRES_PASSWORD=hwpass -e POSTGRES_DB=homework -e POSTGRES_USER=homework -p 5432:5432 -d postgres:16
# Out:
# postgres
# Error: no container with ID or name "postgres" found: no such container
# 366c837477775a226eb708d90973b23b68082e0434633d7c62cfd255109d663c

# %%
# !podman ps -a
# Out:
# CONTAINER ID  IMAGE                                   COMMAND               CREATED                 STATUS       PORTS                   NAMES
# 35611b0be42a  docker.io/hyperledger/fabric-ca:latest  bash -c fabric-ca...  6 days ago              Created      0.0.0.0:7054->7054/tcp  ecm-ca.raiffeisen.ru
# 366c83747777  docker.io/library/postgres:16           postgres              Less than a second ago  Up 1 second  0.0.0.0:5432->5432/tcp  postgres

# %%
# !{ while ! nc -vzw 3 127.0.0.1 5432; do echo waiting for postgres readiness; done; } || true
# Out:
# localhost [127.0.0.1] 5432 (postgresql) open

# %%
# !podman logs postgres
# Out:
# The files belonging to this database system will be owned by user "postgres".
# This user must also own the server process.
#
# The database cluster will be initialized with locale "en_US.utf8".
# The default database encoding has accordingly been set to "UTF8".
# The default text search configuration will be set to "english".
#
# Data page checksums are disabled.
#
# fixing permissions on existing directory /var/lib/postgresql/data ... ok
# creating subdirectories ... ok
# selecting dynamic shared memory implementation ... posix
# selecting default max_connections ... 100
# selecting default shared_buffers ... 128MB
# selecting default time zone ... Etc/UTC
# creating configuration files ... ok
# running bootstrap script ... ok
# performing post-bootstrap initialization ... ok
# syncing data to disk ... ok
#
#
# Success. You can now start the database server using:
#
#     pg_ctl -D /var/lib/postgresql/data -l logfile start
#
# initdb: warning: enabling "trust" authentication for local connections
# initdb: hint: You can change this by editing pg_hba.conf or using the option -A, or --auth-local and --auth-host, the next time you run initdb.
# waiting for server to start....2024-02-18 19:43:16.313 UTC [43] LOG:  starting PostgreSQL 16.1 (Debian 16.1-1.pgdg120+1) on aarch64-unknown-linux-gnu, compiled by gcc (Debian 12.2.0-14) 12.2.0, 64-bit
# 2024-02-18 19:43:16.314 UTC [43] LOG:  listening on Unix socket "/var/run/postgresql/.s.PGSQL.5432"
# 2024-02-18 19:43:16.316 UTC [46] LOG:  database system was shut down at 2024-02-18 19:43:16 UTC
# 2024-02-18 19:43:16.319 UTC [43] LOG:  database system is ready to accept connections
#  done
# server started
# CREATE DATABASE
#
#
# /usr/local/bin/docker-entrypoint.sh: ignoring /docker-entrypoint-initdb.d/*
#
# waiting for server to shut down....2024-02-18 19:43:16.467 UTC [43] LOG:  received fast shutdown request
# 2024-02-18 19:43:16.469 UTC [43] LOG:  aborting any active transactions
# 2024-02-18 19:43:16.471 UTC [43] LOG:  background worker "logical replication launcher" (PID 49) exited with exit code 1
# 2024-02-18 19:43:16.471 UTC [44] LOG:  shutting down
# 2024-02-18 19:43:16.472 UTC [44] LOG:  checkpoint starting: shutdown immediate
# 2024-02-18 19:43:16.521 UTC [44] LOG:  checkpoint complete: wrote 923 buffers (5.6%); 0 WAL file(s) added, 0 removed, 0 recycled; write=0.013 s, sync=0.032 s, total=0.051 s; sync files=301, longest=0.005 s, average=0.001 s; distance=4257 kB, estimate=4257 kB; lsn=0/1912FF0, redo lsn=0/1912FF0
# 2024-02-18 19:43:16.525 UTC [43] LOG:  database system is shut down

# %% [markdown]
# ## Подготавливаем коннект

# %%
import pandas as pd
import psycopg2 as pg
import io
# Out:
# /var/folders/4p/7625v4fd3vnfkh0pgq24l678krwr8q/T/ipykernel_45241/3373786476.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
conn = pg.connect(dbname="homework", user="homework", password="hwpass", host="localhost")
cursor = conn.cursor()

# %% [markdown]
# ## Создаем таблицы

# %%
customer_table = """
CREATE TABLE "customer" (
  "customer_id" serial PRIMARY KEY NOT NULL,
  "first_name" varchar(50) NOT NULL,
  "last_name" varchar(50),
  "gender" varchar(30) NOT NULL,
  "DOB" varchar(50),
  "job_title" varchar(50),
  "job_industry_category" varchar(50),
  "wealth_segment" varchar(50) NOT NULL,
  "deceased_indicator" varchar(50) NOT NULL,
  "owns_car" varchar(30) NOT NULL,
  "address" varchar(50) NOT NULL,
  "postcode" varchar(30) NOT NULL,
  "state" varchar(30) NOT NULL,
  "country" varchar(30) NOT NULL,
  "property_valuation" integer NOT NULL
);
"""
cursor.execute(customer_table)
conn.commit()

# %%
transaction_table = """
CREATE TABLE "transaction" (
  "transaction_id" serial PRIMARY KEY NOT NULL,
  "product_id" integer NOT NULL,
  "customer_id" integer NOT NULL,
  "transaction_date" varchar(30) NOT NULL,
  "online_order" varchar(30),
  "order_status" varchar(30) NOT NULL,
  "brand" varchar(30),
  "product_line" varchar(30),
  "product_class" varchar(30),
  "product_size" varchar(30),
  "list_price" real NOT NULL,
  "standard_cost" real
);
"""

cursor.execute(transaction_table)
conn.commit()

# %%
cursor.execute('ALTER TABLE "transaction" ADD FOREIGN KEY ("customer_id") REFERENCES "customer" ("customer_id");')
conn.commit()

# %% [markdown]
# ## Заливаем данные

# %%
def write_df_to_table(filename: str, table: str, sep: str = ";", null: str = "") -> None:
    with open(filename) as f:
        f.readline() # skip table columns names
        cursor.copy_from(f, table, sep=sep, null=null)
        conn.commit()
    cursor.execute(f"select * from {table} LIMIT 10;")
    conn.commit()
    print(cursor.fetchall())

# %%
write_df_to_table("customer.csv", "customer")
# Out:
# [(1, 'Laraine', 'Medendorp', 'F', '1953-10-12', 'Executive Secretary', 'Health', 'Mass Customer', 'N', 'Yes', '060 Morning Avenue', '2016', 'New South Wales', 'Australia', 10), (2, 'Eli', 'Bockman', 'Male', '1980-12-16', 'Administrative Officer', 'Financial Services', 'Mass Customer', 'N', 'Yes', '6 Meadow Vale Court', '2153', 'New South Wales', 'Australia', 10), (3, 'Arlin', 'Dearle', 'Male', '1954-01-20', 'Recruiting Manager', 'Property', 'Mass Customer', 'N', 'Yes', '0 Holy Cross Court', '4211', 'QLD', 'Australia', 9), (4, 'Talbot', None, 'Male', '1961-10-03', None, 'IT', 'Mass Customer', 'N', 'No', '17979 Del Mar Point', '2448', 'New South Wales', 'Australia', 4), (5, 'Sheila-kathryn', 'Calton', 'Female', '1977-05-13', 'Senior Editor', 'n/a', 'Affluent Customer', 'N', 'Yes', '9 Oakridge Court', '3216', 'VIC', 'Australia', 9), (6, 'Curr', 'Duckhouse', 'Male', '1966-09-16', None, 'Retail', 'High Net Worth', 'N', 'Yes', '4 Delaware Trail', '2210', 'New South Wales', 'Australia', 9), (7, 'Fina', 'Merali', 'Female', '1976-02-23', None, 'Financial Services', 'Affluent Customer', 'N', 'Yes', '49 Londonderry Lane', '2650', 'New South Wales', 'Australia', 4), (8, 'Rod', 'Inder', 'Male', '1962-03-30', 'Media Manager I', 'n/a', 'Mass Customer', 'N', 'No', '97736 7th Trail', '2023', 'New South Wales', 'Australia', 12), (9, 'Mala', 'Lind', 'Female', '1973-03-10', 'Business Systems Development Analyst', 'Argiculture', 'Affluent Customer', 'N', 'Yes', '93405 Ludington Park', '3044', 'VIC', 'Australia', 8), (10, 'Fiorenze', 'Birdall', 'Female', '1988-10-11', 'Senior Quality Engineer', 'Financial Services', 'Mass Customer', 'N', 'Yes', '44339 Golden Leaf Alley', '4557', 'QLD', 'Australia', 4)]

# %%
# Небольшое форматирование чиловых данных
transaction = pd.read_csv("transaction.csv", sep=";", index_col=0)
transaction.list_price = transaction.list_price.map(lambda x: float(x.replace(",", ".")))
transaction.standard_cost = transaction.standard_cost.map(lambda x: x if isinstance(x, float) else float(x.replace(",", ".")))

transaction = transaction[transaction.customer_id <= 4000] # См HW1 ("Убираем транзакции с пользователями, которых не существует в базе)

transaction.to_csv("transaction_fixed.csv", sep=";")
transaction.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 19997 entries, 1 to 20000
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   product_id        19997 non-null  int64
#  1   customer_id       19997 non-null  int64
#  2   transaction_date  19997 non-null  object
#  3   online_order      19637 non-null  object
#  4   order_status      19997 non-null  object
#  5   brand             19800 non-null  object
#  6   product_line      19800 non-null  object
#  7   product_class     19800 non-null  object
#  8   product_size      19800 non-null  object
#  9   list_price        19997 non-null  float64
#  10  standard_cost     19800 non-null  float64
# dtypes: float64(2), int64(2), object(7)
# memory usage: 1.8+ MB

# %%
write_df_to_table("transaction_fixed.csv", "transaction")
# Out:
# [(1, 2, 2950, '25.02.2017', 'False', 'Approved', 'Solex', 'Standard', 'medium', 'medium', 71.49, 53.62), (2, 3, 3120, '21.05.2017', 'True', 'Approved', 'Trek Bicycles', 'Standard', 'medium', 'large', 2091.47, 388.92), (3, 37, 402, '16.10.2017', 'False', 'Approved', 'OHM Cycles', 'Standard', 'low', 'medium', 1793.43, 248.82), (4, 88, 3135, '31.08.2017', 'False', 'Approved', 'Norco Bicycles', 'Standard', 'medium', 'medium', 1198.46, 381.1), (5, 78, 787, '01.10.2017', 'True', 'Approved', 'Giant Bicycles', 'Standard', 'medium', 'large', 1765.3, 709.48), (6, 25, 2339, '08.03.2017', 'True', 'Approved', 'Giant Bicycles', 'Road', 'medium', 'medium', 1538.99, 829.65), (7, 22, 1542, '21.04.2017', 'True', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 60.34, 45.26), (8, 15, 2459, '15.07.2017', 'False', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1292.84, 13.44), (9, 67, 1305, '10.08.2017', 'False', 'Approved', 'Solex', 'Standard', 'medium', 'large', 1071.23, 380.74), (10, 12, 3262, '30.08.2017', 'True', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1231.15, 161.6)]

# %%
def execute(statement: str) -> None:
    cursor.execute(statement)
    conn.commit()
    res = cursor.fetchall()
    print(len(res))
    print(res)

# %% [markdown]
# ## Задание №1

# %%
execute("""
SELECT 
  DISTINCT brand 
FROM 
  transaction 
WHERE 
  standard_cost > 1500
""")
# Out:
# 4
# [('Solex',), ('Giant Bicycles',), ('OHM Cycles',), ('Trek Bicycles',)]

# %% [markdown]
# ## Задание №2

# %%
execute("""
SELECT 
  * 
FROM 
  transaction 
WHERE 
  order_status = 'Approved' 
  and TO_DATE(transaction_date, 'DD.MM.YYYY') BETWEEN '2017-04-01' 
  AND '2017-04-09';
""")
# Out:
# 531
# [(17, 79, 2426, '03.04.2017', 'False', 'Approved', 'Norco Bicycles', 'Standard', 'medium', 'medium', 1555.58, 818.01), (19, 54, 2268, '06.04.2017', 'True', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1292.84, 13.44), (23, 37, 2001, '08.04.2017', 'True', 'Approved', 'OHM Cycles', 'Standard', 'low', 'medium', 1793.43, 248.82), (83, 0, 3398, '01.04.2017', 'True', 'Approved', 'OHM Cycles', 'Standard', 'medium', 'medium', 235.63, 125.07), (89, 0, 2682, '04.04.2017', 'True', 'Approved', 'OHM Cycles', 'Road', 'high', 'large', 12.01, 7.21), (126, 53, 773, '01.04.2017', 'False', 'Approved', 'OHM Cycles', 'Standard', 'medium', 'medium', 795.34, 101.58), (146, 41, 3261, '06.04.2017', 'True', 'Approved', 'Solex', 'Road', 'medium', 'medium', 416.98, 312.74), (154, 3, 3383, '06.04.2017', 'True', 'Approved', 'Trek Bicycles', 'Standard', 'medium', 'large', 2091.47, 388.92), (220, 10, 1502, '09.04.2017', 'True', 'Approved', 'WeareA2B', 'Touring', 'medium', 'medium', 1466.68, 363.25), (228, 13, 821, '04.04.2017', 'True', 'Approved', 'Solex', 'Standard', 'medium', 'medium', 1163.89, 589.27), (280, 93, 2487, '08.04.2017', 'False', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1065.03, 230.09), (290, 55, 624, '05.04.2017', 'True', 'Approved', 'Trek Bicycles', 'Road', 'medium', 'large', 1894.19, 598.76), (304, 12, 2745, '07.04.2017', 'False', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1231.15, 161.6), (526, 20, 827, '02.04.2017', 'True', 'Approved', 'Trek Bicycles', 'Standard', 'medium', 'small', 1775.81, 1580.47), (534, 14, 1517, '08.04.2017', 'False', 'Approved', 'Trek Bicycles', 'Standard', 'medium', 'small', 1386.84, 1234.29), (563, 97, 3071, '05.04.2017', 'False', 'Approved', 'Solex', 'Standard', 'medium', 'large', 202.62, 151.96), (669, 68, 3420, '07.04.2017', 'False', 'Approved', 'OHM Cycles', 'Standard', 'medium', 'medium', 1636.9, 44.71), (671, 67, 2874, '09.04.2017', 'False', 'Approved', 'Norco Bicycles', 'Road', 'medium', 'medium', 544.05, 376.84), (767, 31, 2554, '06.04.2017', 'True', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 752.64, 205.36), (898, 0, 1710, '03.04.2017', 'True', 'Approved', 'Norco Bicycles', 'Road', 'medium', 'medium', 543.39, 407.54), (904, 67, 3195, '02.04.2017', 'False', 'Approved', 'Norco Bicycles', 'Road', 'medium', 'medium', 544.05, 376.84), (943, 48, 2954, '08.04.2017', 'False', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1762.96, 950.52), (948, 97, 1601, '09.04.2017', 'False', 'Approved', 'Solex', 'Standard', 'medium', 'large', 202.62, 151.96), (1044, 54, 1839, '01.04.2017', 'True', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1807.45, 778.69), (1049, 97, 1107, '07.04.2017', 'True', 'Approved', 'OHM Cycles', 'Road', 'medium', 'medium', 742.54, 667.4), (1073, 80, 794, '05.04.2017', 'True', 'Approved', 'OHM Cycles', 'Touring', 'low', 'medium', 1073.07, 933.84), (1074, 33, 931, '05.04.2017', 'False', 'Approved', 'Giant Bicycles', 'Standard', 'medium', 'small', 1311.44, 1167.18), (1125, 41, 1273, '07.04.2017', 'True', 'Approved', 'Solex', 'Road', 'medium', 'medium', 416.98, 312.74), (1161, 42, 2883, '02.04.2017', 'True', 'Approved', 'OHM Cycles', 'Road', 'medium', 'small', 1810.0, 1610.9), (1187, 68, 1951, '06.04.2017', 'False', 'Approved', 'OHM Cycles', 'Standard', 'medium', 'medium', 1636.9, 44.71), (1197, 0, 2234, '04.04.2017', 'False', 'Approved', None, None, None, None, 756.31, None), (1235, 18, 2478, '04.04.2017', 'True', 'Approved', 'Solex', 'Standard', 'medium', 'medium', 575.27, 431.45), (1242, 54, 457, '03.04.2017', 'True', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1807.45, 778.69), (1254, 10, 1830, '04.04.2017', 'False', 'Approved', 'Solex', 'Standard', 'medium', 'medium', 1945.43, 333.18), (1275, 97, 27, '08.04.2017', 'False', 'Approved', 'Solex', 'Standard', 'medium', 'large', 202.62, 151.96), (1294, 12, 2311, '09.04.2017', 'False', 'Approved', 'WeareA2B', 'Standard', 'medium', 'medium', 1231.15, 161.6), (1342, 88, 226 ...

# %% [markdown]
# ## Задание №3

# %%
execute("""
SELECT 
  DISTINCT job_title 
FROM 
  customer 
WHERE 
  (
    job_industry_category = 'IT' 
    OR job_industry_category = 'Financial Services'
  ) 
  AND job_title :: varchar(10) like 'Senior%'
""")
# Out:
# 6
# [('Senior Cost Accountant',), ('Senior Developer',), ('Senior Editor',), ('Senior Financial Analyst',), ('Senior Quality Engineer',), ('Senior Sales Associate',)]

# %% [markdown]
# ## Задание №4

# %%
execute("""
SELECT 
  DISTINCT brand 
FROM 
  transaction 
WHERE 
  customer_id IN (
    SELECT 
      customer_id 
    FROM 
      customer 
    WHERE 
      job_industry_category = 'Financial Services'
  )
""")
# Out:
# 7
# [('Giant Bicycles',), ('Norco Bicycles',), ('OHM Cycles',), ('Solex',), ('Trek Bicycles',), ('WeareA2B',), (None,)]

# %% [markdown]
# ## Задание №5

# %%
execute("""
SELECT 
  * 
FROM 
  customer 
WHERE 
  customer_id IN (
    SELECT 
      customer_id 
    FROM 
      transaction 
    WHERE 
      brand = 'Giant Bicycles' 
      OR brand = 'Norco Bicycles' 
      OR brand = 'Trek Bicycles'
  ) 
LIMIT 
  10
""")
# Out:
# 10
# [(1, 'Laraine', 'Medendorp', 'F', '1953-10-12', 'Executive Secretary', 'Health', 'Mass Customer', 'N', 'Yes', '060 Morning Avenue', '2016', 'New South Wales', 'Australia', 10), (2, 'Eli', 'Bockman', 'Male', '1980-12-16', 'Administrative Officer', 'Financial Services', 'Mass Customer', 'N', 'Yes', '6 Meadow Vale Court', '2153', 'New South Wales', 'Australia', 10), (3, 'Arlin', 'Dearle', 'Male', '1954-01-20', 'Recruiting Manager', 'Property', 'Mass Customer', 'N', 'Yes', '0 Holy Cross Court', '4211', 'QLD', 'Australia', 9), (4, 'Talbot', None, 'Male', '1961-10-03', None, 'IT', 'Mass Customer', 'N', 'No', '17979 Del Mar Point', '2448', 'New South Wales', 'Australia', 4), (5, 'Sheila-kathryn', 'Calton', 'Female', '1977-05-13', 'Senior Editor', 'n/a', 'Affluent Customer', 'N', 'Yes', '9 Oakridge Court', '3216', 'VIC', 'Australia', 9), (6, 'Curr', 'Duckhouse', 'Male', '1966-09-16', None, 'Retail', 'High Net Worth', 'N', 'Yes', '4 Delaware Trail', '2210', 'New South Wales', 'Australia', 9), (7, 'Fina', 'Merali', 'Female', '1976-02-23', None, 'Financial Services', 'Affluent Customer', 'N', 'Yes', '49 Londonderry Lane', '2650', 'New South Wales', 'Australia', 4), (8, 'Rod', 'Inder', 'Male', '1962-03-30', 'Media Manager I', 'n/a', 'Mass Customer', 'N', 'No', '97736 7th Trail', '2023', 'New South Wales', 'Australia', 12), (9, 'Mala', 'Lind', 'Female', '1973-03-10', 'Business Systems Development Analyst', 'Argiculture', 'Affluent Customer', 'N', 'Yes', '93405 Ludington Park', '3044', 'VIC', 'Australia', 8), (10, 'Fiorenze', 'Birdall', 'Female', '1988-10-11', 'Senior Quality Engineer', 'Financial Services', 'Mass Customer', 'N', 'Yes', '44339 Golden Leaf Alley', '4557', 'QLD', 'Australia', 4)]

# %% [markdown]
# ## Задание №6

# %%
execute("""
SELECT 
  * 
FROM 
  customer 
WHERE 
  customer_id NOT IN (
    SELECT 
      customer_id 
    FROM 
      transaction
  )
""")
# Out:
# 507
# [(852, 'Andie', 'Bonney', 'Female', '2000-11-04', 'Compensation Analyst', 'Financial Services', 'Affluent Customer', 'N', 'Yes', '94 Anhalt Way', '3139', 'VIC', 'Australia', 7), (869, 'Addia', 'Abels', 'Female', '1984-03-11', 'Account Representative I', 'Financial Services', 'High Net Worth', 'N', 'Yes', '02377 Maywood Trail', '2287', 'NSW', 'Australia', 7), (1373, 'Shaylynn', 'Epsley', 'Female', '1958-09-23', 'Director of Sales', 'Financial Services', 'Mass Customer', 'N', 'Yes', '0 Grasskamp Pass', '3170', 'VIC', 'Australia', 10), (2074, 'Roslyn', 'Rawdall', 'Female', '1997-06-11', None, 'Financial Services', 'Mass Customer', 'N', 'No', '95483 Washington Junction', '2505', 'NSW', 'Australia', 9), (2660, 'Hunt', 'Scollard', 'Male', '1963-11-15', None, 'Retail', 'High Net Worth', 'N', 'Yes', '359 Briar Crest Road', '2155', 'NSW', 'Australia', 10), (3229, 'Carrol', 'Gheorghie', 'Male', '1964-10-18', 'Sales Representative', 'Retail', 'High Net Worth', 'N', 'Yes', '44 Service Alley', '3023', 'VIC', 'Australia', 7), (3236, 'Edsel', 'Arguile', 'Male', '1993-04-01', None, 'Manufacturing', 'Mass Customer', 'N', 'Yes', '3 Pepper Wood Point', '2760', 'NSW', 'Australia', 8), (3501, 'Kayla', 'Alentyev', 'Female', '1970-01-19', 'Operator', 'Telecommunications', 'Mass Customer', 'N', 'Yes', '5854 Weeping Birch Avenue', '2022', 'NSW', 'Australia', 10), (3502, 'Wilfrid', 'Cleaves', 'Male', '1997-10-16', 'Senior Sales Associate', 'Retail', 'High Net Worth', 'N', 'Yes', '2 Clarendon Point', '2194', 'NSW', 'Australia', 7), (3503, 'Tootsie', 'Rafter', 'Female', '1979-03-12', 'Financial Advisor', 'Financial Services', 'Affluent Customer', 'N', 'Yes', '88979 Hazelcrest Way', '3555', 'VIC', 'Australia', 3), (3504, 'Keriann', 'Perdue', 'Female', '1963-07-06', 'Business Systems Development Analyst', 'Manufacturing', 'Mass Customer', 'N', 'Yes', '7555 Springview Crossing', '3195', 'VIC', 'Australia', 10), (3505, 'Dolly', 'Scallan', 'Female', '1974-08-06', None, 'Retail', 'Mass Customer', 'N', 'No', '04240 Prentice Plaza', '3031', 'VIC', 'Australia', 9), (3506, 'Mercy', 'Donisi', 'Female', '1975-06-18', 'Web Designer I', 'Financial Services', 'Mass Customer', 'N', 'No', '35280 Harper Junction', '2700', 'NSW', 'Australia', 2), (3507, 'Christoph', 'Greatreax', 'Male', '1955-03-03', 'Physical Therapy Assistant', 'Financial Services', 'Mass Customer', 'N', 'No', '08479 Hazelcrest Street', '3340', 'VIC', 'Australia', 4), (3508, 'Malvin', 'Marre', 'Male', '1986-08-09', 'Pharmacist', 'Health', 'Mass Customer', 'N', 'No', '70 Oakridge Pass', '2019', 'NSW', 'Australia', 10), (3509, 'Janine', 'Hesey', 'Female', '1978-11-22', 'Pharmacist', 'Health', 'Mass Customer', 'N', 'Yes', '56873 Buena Vista Crossing', '2035', 'NSW', 'Australia', 9), (3510, 'Jemima', 'Izaac', 'U', None, 'Safety Technician II', 'IT', 'Affluent Customer', 'N', 'Yes', '7 Rieder Street', '3155', 'VIC', 'Australia', 7), (3511, 'Willem', 'Spraging', 'Male', '1966-12-31', 'Food Chemist', 'Health', 'Affluent Customer', 'N', 'No', '3528 Granby Circle', '4825', 'QLD', 'Australia', 5), (3512, 'Vladimir', 'Abramowsky', 'Male', '1994-03-24', 'VP Accounting', 'Financial Services', 'Mass Customer', 'N', 'Yes', '16 Vahlen Trail', '2152', 'NSW', 'Australia', 10), (3513, 'Enriqueta', 'Waterhowse', 'U', None, 'Internal Auditor', 'IT', 'Affluent Customer', 'N', 'Yes', '977 Arapahoe Trail', '4121', 'QLD', 'Australia', 8), (3514, 'Darcy', 'Ilett', 'Male', '1962-08-24', 'Environmental Specialist', 'n/a', 'Mass Customer', 'N', 'No', '31331 Old Shore Crossing', '2211', 'NSW', 'Australia', 8), (3515, 'Leelah', 'Pynner', 'Female', '1975-01-14', 'Staff Scientist', 'Telecommunications', 'High Net Worth', 'N', 'Yes', '51757 Weeping Birch Center', '2470', 'NSW', 'Australia', 5), (3516, 'Diarmid', 'Vearnals', 'Male', '1977-04-30', None, 'Property', 'Mass Customer', 'N', 'Yes', '25 Schurz Avenue', '2071', 'NSW', 'Australia', 12), (3517, 'Domeniga', 'Terney', 'Female', '1957-07-04', 'Accounting Assistant IV', 'n/a', 'Mass Cu ...

# %% [markdown]
# ## Задание №7

# %%
execute("""
SELECT 
  * 
FROM 
  customer 
WHERE 
  job_industry_category = 'IT' 
  AND customer_id IN (
    SELECT 
      customer_id 
    FROM 
      transaction 
    WHERE 
      standard_cost = (
        SELECT 
          MAX(standard_cost) 
        FROM 
          transaction
      )
  )
""")
# Out:
# 9
# [(34, 'Jephthah', 'Bachmann', 'U', '1843-12-21', 'Legal Assistant', 'IT', 'Affluent Customer', 'N', 'No', '90 Lawn Parkway', '4805', 'QLD', 'Australia', 4), (893, 'Gibby', 'Fearnley', 'Male', '1983-09-11', 'Geologist I', 'IT', 'Mass Customer', 'N', 'No', '6382 Bayside Street', '2153', 'NSW', 'Australia', 10), (975, 'Goldarina', 'Rzehorz', 'U', None, 'Automation Specialist IV', 'IT', 'Mass Customer', 'N', 'No', '938 Monica Park', '3173', 'VIC', 'Australia', 9), (1672, 'Sharla', 'Creebo', 'Female', '1963-04-27', 'Design Engineer', 'IT', 'Affluent Customer', 'N', 'Yes', '1 Morning Circle', '2250', 'NSW', 'Australia', 8), (1773, 'Nickolas', 'Guittet', 'U', None, None, 'IT', 'Mass Customer', 'N', 'Yes', '835 West Hill', '2118', 'NSW', 'Australia', 11), (1918, 'Devin', 'Sandeson', 'U', None, 'Staff Accountant II', 'IT', 'Affluent Customer', 'N', 'No', '51763 Carey Place', '3056', 'VIC', 'Australia', 7), (2913, 'Padraic', 'Bonnar', 'Male', '1955-07-11', 'VP Quality Control', 'IT', 'Affluent Customer', 'N', 'Yes', '937 Sloan Center', '4118', 'QLD', 'Australia', 6), (3151, 'Thorn', 'Choffin', 'U', None, 'Senior Developer', 'IT', 'Affluent Customer', 'N', 'Yes', '5323 Chive Avenue', '2486', 'NSW', 'Australia', 7), (3473, 'Sanderson', 'Alloway', 'U', None, 'Analog Circuit Design manager', 'IT', 'Mass Customer', 'N', 'No', '3 Roxbury Street', '2261', 'NSW', 'Australia', 7)]

# %% [markdown]
# ## Задание №8

# %%
execute("""
SELECT 
  * 
FROM 
  customer 
WHERE 
  (
    job_industry_category = 'IT' 
    OR job_industry_category = 'Health'
  ) 
  AND customer_id IN (
    SELECT 
      customer_id 
    FROM 
      transaction 
    WHERE 
      order_status = 'Approved' 
      AND TO_DATE(transaction_date, 'DD.MM.YYYY') BETWEEN '2017-07-07' 
      AND '2017-07-17'
  )
""")
# Out:
# 115
# [(1489, 'Mead', 'Wollard', 'Male', '1993-05-13', 'Teacher', 'Health', 'Mass Customer', 'N', 'No', '9 Sycamore Pass', '2287', 'NSW', 'Australia', 5), (753, 'Josy', 'St. Quentin', 'Female', '1970-03-07', 'Food Chemist', 'Health', 'Affluent Customer', 'Y', 'Yes', '195 Knutson Place', '4019', 'QLD', 'Australia', 8), (1091, 'Keith', 'Housden', 'Male', '1980-04-15', None, 'Health', 'Mass Customer', 'N', 'No', '04 Onsgard Center', '2101', 'NSW', 'Australia', 9), (2285, 'Maritsa', 'Bellison', 'Female', '1973-10-27', 'Quality Control Specialist', 'Health', 'High Net Worth', 'N', 'No', '09356 Badeau Drive', '3630', 'VIC', 'Australia', 1), (350, 'Carmela', 'Jesper', 'Female', '1977-12-09', 'Clinical Specialist', 'Health', 'Mass Customer', 'N', 'Yes', '0293 Porter Crossing', '2830', 'NSW', 'Australia', 5), (424, 'Dennie', 'Eunson', 'Male', '1978-01-25', 'Research Nurse', 'Health', 'High Net Worth', 'N', 'No', '8 Moland Pass', '2065', 'NSW', 'Australia', 10), (1683, 'Brenn', 'Bacon', 'U', None, 'Budget/Accounting Analyst I', 'IT', 'Mass Customer', 'N', 'Yes', '86 Morningstar Junction', '2031', 'NSW', 'Australia', 12), (22, 'Deeanne', 'Durtnell', 'Female', '1962-12-10', None, 'IT', 'Mass Customer', 'N', 'No', '52 Carey Alley', '4740', 'QLD', 'Australia', 5), (2463, 'Krystle', 'Jovicevic', 'Female', '1978-01-30', 'Pharmacist', 'Health', 'Mass Customer', 'N', 'No', '083 Farragut Avenue', '2540', 'NSW', 'Australia', 7), (3211, 'Betsy', 'Cosh', 'Female', '1993-06-12', 'Automation Specialist II', 'Health', 'High Net Worth', 'N', 'Yes', '743 Karstens Point', '2122', 'NSW', 'Australia', 11), (1166, 'Fannie', 'Devil', 'Female', '1972-12-05', 'Quality Control Specialist', 'Health', 'Affluent Customer', 'N', 'No', '378 Prentice Point', '4064', 'QLD', 'Australia', 9), (2953, 'Hector', 'Carwithan', 'Male', '1972-10-26', 'Recruiting Manager', 'Health', 'High Net Worth', 'N', 'Yes', '02555 Sloan Way', '2259', 'NSW', 'Australia', 8), (2366, 'Idette', 'Mapam', 'Female', '1975-06-15', 'Web Designer I', 'Health', 'Mass Customer', 'N', 'Yes', '89 Oak Hill', '2508', 'NSW', 'Australia', 10), (331, 'Ford', 'Groucock', 'Male', '1998-09-23', 'Desktop Support Technician', 'Health', 'Mass Customer', 'N', 'Yes', '82 Mcbride Trail', '3223', 'VIC', 'Australia', 6), (1578, 'Andreas', 'Bazely', 'Male', '1978-04-14', None, 'Health', 'High Net Worth', 'N', 'Yes', '85301 John Wall Road', '2101', 'NSW', 'Australia', 11), (1024, 'Rhodia', "D'Onise", 'Female', '1992-06-05', 'Social Worker', 'Health', 'High Net Worth', 'N', 'Yes', '15393 Cody Lane', '2046', 'NSW', 'Australia', 9), (769, 'Cameron', 'Letherbury', 'Male', '1961-12-28', 'Analog Circuit Design manager', 'IT', 'Mass Customer', 'N', 'No', '88 Bay Drive', '4305', 'QLD', 'Australia', 3), (2690, 'Sissie', 'Giordano', 'Female', '1980-11-06', 'Registered Nurse', 'Health', 'Affluent Customer', 'N', 'Yes', '99565 Warrior Alley', '4510', 'QLD', 'Australia', 3), (2610, 'Arliene', 'Bartolijn', 'Female', '1954-04-30', 'Account Coordinator', 'IT', 'Mass Customer', 'N', 'No', '93124 Monterey Plaza', '3000', 'VIC', 'Australia', 7), (2684, 'Erastus', 'Payley', 'Male', '1964-03-14', 'Health Coach IV', 'Health', 'Mass Customer', 'N', 'Yes', '22 Moulton Place', '4878', 'QLD', 'Australia', 4), (661, 'Cinderella', 'Haslen', 'Female', '1988-05-07', 'Sales Associate', 'IT', 'High Net Worth', 'N', 'No', '77006 Nelson Point', '4171', 'QLD', 'Australia', 10), (414, 'Thorin', 'Grimoldby', 'Male', '1976-07-16', 'Social Worker', 'Health', 'High Net Worth', 'N', 'No', '713 Eastwood Terrace', '2360', 'NSW', 'Australia', 1), (872, 'Suki', 'Ivachyov', 'Female', '1971-04-28', 'Structural Engineer', 'IT', 'Mass Customer', 'N', 'No', '3 Glacier Hill Parkway', '2196', 'NSW', 'Australia', 10), (428, 'Freida', 'Everil', 'Female', '1977-05-03', 'Structural Engineer', 'Health', 'High Net Worth', 'N', 'Yes', '9 Lukken Parkway', '2065', 'NSW', 'Australia', 10), (1005, 'Kalila', 'Birtwistle', 'Female', '1967-09-15', 'Design Engineer', 'IT', 'High Net Worth', ' ...

# %% [markdown]
# ## Закрываем коннекты

# %%
cursor.close()
conn.close()
